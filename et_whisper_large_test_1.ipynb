# %% [markdown]
# <a href="https://colab.research.google.com/github/monoramasn/Speech_fairness/blob/main/et_whisper_large_test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install librosa
# !pip install evaluate>=0.30
# !pip install jiwer
# !pip install gradio
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-h4pbppxp
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-h4pbppxp
#   Resolved https://github.com/huggingface/transformers to commit 2c658b5a4282f2e824b4e23dc3bcda7ef27d5827
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.0.dev0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.0.dev0) (2023.11.17)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.36.0.dev0-py3-none-any.whl size=8119970 sha256=0cc30485dfcb5817e2226f77497fada440f31fce68c5217495d37661db14e28d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cyg9f7kz/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed transformers-4.36.0.dev0
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.11.17)
# Collecting jiwer
#   Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 23.6 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.3 rapidfuzz-3.5.2
# Collecting gradio
#   Downloading gradio-4.7.1-py3-none-any.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 70.2 MB/s eta 0:00:00
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.2.2)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.104.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 12.5 MB/s eta 0:00:00
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.7.0 (from gradio)
#   Downloading gradio_client-0.7.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.7/302.7 kB 37.5 MB/s eta 0:00:00
# Collecting httpx (from gradio)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.19.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.23.5)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (9.4.0)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 45.3 MB/s eta 0:00:00
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.31.0)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.5.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.24.0.post1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.7.0->gradio) (2023.6.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.7.0->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.14.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 104.4 MB/s eta 0:00:00
# Collecting typing-extensions~=4.0 (from gradio)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2023.11.17)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (13.7.0)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 10.8 MB/s eta 0:00:00
# Collecting httpcore==1.* (from httpx->gradio)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=6b41c4e11f3b7e01b48801c72db7925f41c410e73cedcc93cf073b43412d95f0
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, typing-extensions, tomlkit, shellingham, semantic-version, python-multipart, orjson, h11, colorama, annotated-types, aiofiles, uvicorn, starlette, pydantic-core, httpcore, pydantic, httpx, gradio-client, fastapi, gradio
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 annotated-types-0.6.0 colorama-0.4.6 fastapi-0.104.1 ffmpy-0.3.1 gradio-4.7.1 gradio-client-0.7.0 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 orjson-3.9.10 pydantic-2.5.2 pydantic-core-2.14.5 pydub-0.25.1 python-multipart-0.0.6 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.27.0 tomlkit-0.12.0 typing-extensions-4.8.0 uvicorn-0.24.0.post1 websockets-11.0.3

# %%
import torch
from transformers import AutoFeatureExtractor, WhisperModel
from datasets import load_dataset

# %%
import os
import numpy as np

try:
    import tensorflow  # required in Colab to avoid protobuf compatibility issues
except ImportError:
    pass

import torch
import pandas as pd
import torchaudio

from tqdm.notebook import tqdm

# %%
voxpopuli_data = load_dataset("facebook/voxpopuli", "et", split="test")
#column_name = "audio, normalized_text"
# Out:
# Downloading builder script:   0%|          | 0.00/8.84k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/304k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/18.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/18.7k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/279M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/16.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.8M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
voxpopuli_data
# Out:
# Dataset({
#     features: ['audio_id', 'language', 'audio', 'raw_text', 'normalized_text', 'gender', 'speaker_id', 'is_gold_transcript', 'accent'],
#     num_rows: 51
# })

# %%
# !pip install openai-whisper
import whisper
#model = whisper.load_model("base")
# Out:
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.10/dist-packages (20231117)
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.1.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (4.66.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (10.1.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper) (3.13.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (4.8.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper) (1.3.0)

# %%
model = whisper.load_model("large")
# Out:
# 100%|██████████████████████████████████████| 2.88G/2.88G [00:23<00:00, 130MiB/s]

# %%
from transformers import WhisperForConditionalGeneration, WhisperFeatureExtractor,WhisperTokenizer
from datasets import load_dataset
import torch
from tqdm import tqdm
from jiwer import wer

# %%
Gender=voxpopuli_data['gender']
Audio=voxpopuli_data['audio']
text=voxpopuli_data['normalized_text']
Gender=pd.DataFrame(Gender)
Audio=pd.DataFrame(Audio)
text=pd.DataFrame(text)

# %%
text
# Out:
#                                                     0
# 0   esiteks on oluline et euroopa liit tuleks välj...
# 1   härra eesistuja juba süüria kodusõda tekitas s...
# 2   ja lõpetuseks tuleb kehtestada rahvusvahelised...
# 3   eelnimetatud rahvusvahelise õiguse rikkumised ...
# 4   mulle meeldib väga punkt üks kus öeldakse et i...
# 5   ja ma loeksin ette hea meelega resolutsiooni p...
# 6   siin on suur tähtsus mitteformaalse ja informa...
# 7   elu kinnitas taas kord et ida eurooplaste kann...
# 8   euroopa liidule ja eriti rahva poolt otse vali...
# 9   õigusriiki ja demokraatiat tugevdavaid reforme...
# 10  samas on mitme idapartnerluse riigi puhul jätk...
# 11  ja energialiiduna võib ühel päeval olla palju ...
# 12  me oleme olnud liiga palju üllatunud venemaa k...
# 13  muidugi ma eeldan seda et ukraina jätkab oma r...
# 14  põgenikud nende abistamine peab olema euroopa ...
# 15  meie kohus on näidata et selline käitumine ei ...
# 16  kuid globaalne majanduskriis õõnestas meie usk...
# 17  kahjuks andis eilsel väliskomisjoni ja moldova...
# 18  need arengud ei toimu mitte ainult tänu riigia...
# 19  novembrikuisel idapartnerluse tippkohtumisel t...
# 20  ettepanekud peaksid hõlmama ka reforme et liht...
# 21         ö universaalsete meetmete kooskõlastamine.
# 22  kuidas te hindate viimasel ajal serbia mõju om...
# 23  need konfliktid pidurdavad oluliselt meie idap...
# 24  raportiga teeme sammu euroopa sotsiaalstandart...
# 25  aga vaatamata sellele me pingutasime kärpisime...
# 26  me tahame teada kuidas käitus politsei valimis...
# 27  minu küsimus puudutab selles piirkonnas olulis...
# 28  seetõttu on väga oluline säilitada euroopa lii...
# 29  me kordame resolutsioonis üle et venemaal dets...
# 30  aga venemaa ei ole vangistanud mitte ainult uk...
# 31  kuigi tegemist on väikese ja abivajava riigiga...
# 32  ja ma toetasin seda resolutsiooni ja jagan pal...
# 33  inimesed põgenevad nii assadi režiimi kui ka i...
# 34  me ei lepi sellega kuna eurointegratsioon tähe...
# 35  seni kuni euroopa liit arutab analüüsib ja mõt...
# 36  mina nii ei arva ja seetõttu ma hääletasin ka ...
# 37  mul on hea meel et eesti on euroopa liidu eesi...
# 38  me peame leidma ühise valemi ühise arusaama mi...
# 39  paindlik haridustee saab olla abiks eeskätt ha...
# 40  euroopa liidu ja moldova suhted jäävad endisel...
# 41  nagu näiteks tööjõus osalemise määr noorte töö...
# 42  mul on väga kahju et fraktsioon gue hääletab s...
# 43  küll aga toetan seda resolutsiooni kui komprom...
# 44  enamgi veel need näitajad muudetakse võrdseks ...
# 45  käivitatud on ka riigihangete e platvorm ja võ...
# 46  eesmärk peab olema ebavõrdsuse ja palgavaesuse...
# 47  nimelt ütleb punkt kuus seda et me kutsume ven...
# 48  vajadusel tuleb arenguabi vahendeid ka suunata...
# 49  austatud istungi juhataja! mul on väga hea mee...
# 50  see et venemaa on asunud süürias tegutsema ei ...

# %%
Gender.columns=['Gender']
text.columns=['Transcript']

# %%
file=pd.concat([Gender, text, Audio],axis=1)
file
# Out:
#     Gender                                         Transcript  \
# 0     male  esiteks on oluline et euroopa liit tuleks välj...
# 1     male  härra eesistuja juba süüria kodusõda tekitas s...
# 2     male  ja lõpetuseks tuleb kehtestada rahvusvahelised...
# 3   female  eelnimetatud rahvusvahelise õiguse rikkumised ...
# 4   female  mulle meeldib väga punkt üks kus öeldakse et i...
# 5   female  ja ma loeksin ette hea meelega resolutsiooni p...
# 6   female  siin on suur tähtsus mitteformaalse ja informa...
# 7   female  elu kinnitas taas kord et ida eurooplaste kann...
# 8   female  euroopa liidule ja eriti rahva poolt otse vali...
# 9     male  õigusriiki ja demokraatiat tugevdavaid reforme...
# 10    male  samas on mitme idapartnerluse riigi puhul jätk...
# 11    male  ja energialiiduna võib ühel päeval olla palju ...
# 12    male  me oleme olnud liiga palju üllatunud venemaa k...
# 13  female  muidugi ma eeldan seda et ukraina jätkab oma r...
# 14    male  põgenikud nende abistamine peab olema euroopa ...
# 15  female  meie kohus on näidata et selline käitumine ei ...
# 16  female  kuid globaalne majanduskriis õõnestas meie usk...
# 17  female  kahjuks andis eilsel väliskomisjoni ja moldova...
# 18  female  need arengud ei toimu mitte ainult tänu riigia...
# 19    male  novembrikuisel idapartnerluse tippkohtumisel t...
# 20  female  ettepanekud peaksid hõlmama ka reforme et liht...
# 21  female         ö universaalsete meetmete kooskõlastamine.
# 22    male  kuidas te hindate viimasel ajal serbia mõju om...
# 23    male  need konfliktid pidurdavad oluliselt meie idap...
# 24  female  raportiga teeme sammu euroopa sotsiaalstandart...
# 25  female  aga vaatamata sellele me pingutasime kärpisime...
# 26  female  me tahame teada kuidas käitus politsei valimis...
# 27    male  minu küsimus puudutab selles piirkonnas olulis...
# 28    male  seetõttu on väga oluline säilitada euroopa lii...
# 29  female  me kordame resolutsioonis üle et venemaal dets...
# 30  female  aga venemaa ei ole vangistanud mitte ainult uk...
# 31  female  kuigi tegemist on väikese ja abivajava riigiga...
# 32  female  ja ma toetasin seda resolutsiooni ja jagan pal...
# 33    male  inimesed põgenevad nii assadi režiimi kui ka i...
# 34  female  me ei lepi sellega kuna eurointegratsioon tähe...
# 35    male  seni kuni euroopa liit arutab analüüsib ja mõt...
# 36  female  mina nii ei arva ja seetõttu ma hääletasin ka ...
# 37    male  mul on hea meel et eesti on euroopa liidu eesi...
# 38  female  me peame leidma ühise valemi ühise arusaama mi...
# 39  female  paindlik haridustee saab olla abiks eeskätt ha...
# 40  female  euroopa liidu ja moldova suhted jäävad endisel...
# 41  female  nagu näiteks tööjõus osalemise määr noorte töö...
# 42    male  mul on väga kahju et fraktsioon gue hääletab s...
# 43  female  küll aga toetan seda resolutsiooni kui komprom...
# 44  female  enamgi veel need näitajad muudetakse võrdseks ...
# 45  female  käivitatud on ka riigihangete e platvorm ja võ...
# 46  female  eesmärk peab olema ebavõrdsuse ja palgavaesuse...
# 47  female  nimelt ütleb punkt kuus seda et me kutsume ven...
# 48    male  vajadusel tuleb arenguabi vahendeid ka suunata...
# 49  female  austatud istungi juhataja! mul on väga hea mee...
# 50    male  see et venemaa on asunud süürias tegutsema ei ...
#
#                                                  path  \
# 0   /root/.cache/huggingface/datasets/downloads/ex...
# 1   /root/.cache/huggingface/datasets/downloads/ex...
# 2   /root/.cache/huggingface/datasets/downloads/ex...
# 3   /root/.cache/huggingface/datasets/downloads/ex...
# 4   /root/.cache/huggingface/datasets/downloads/ex...
# 5   /root/.cache/huggingface/datasets/downloads/ex...
# 6   /root/.cache/huggingface/datasets/downloads/ex...
# 7   /root/.cache/huggingface/datasets/downloads/ex...
# 8   /root/.cache/huggingface/datasets/downloads/ex...
# 9   /root/.cache/huggingface/datasets/downloads/ex...
# 10  /root/.cache/huggingface/datasets/downloads/ex...
# 11  /root/.cache/huggingface/datasets/downloads/ex...
# 12  /root/.cache/huggingface/datasets/downloads/ex...
# 13  /root/.cache/huggingface/datasets/downloads/ex...
# 14  /root/.cache/huggingface/datasets/downloads/ex...
# 15  /root/.cache/huggingface/datasets/downloads/ex...
# 16  /root/.cache/huggingface/datasets/downloads/ex...
# 17  /root/.cache/huggingface/datasets/downloads/ex...
# 18  /root/.cache/huggingface/datasets/downloads/ex...
# 19  /root/.cache/huggingface/datasets/downloads/ex...
# 20  /root/.cache/huggingface/datasets/downloads/ex...
# 21  /root/.cache/huggingface/datasets/downloads/ex...
# 22  /root/.cache/huggingface/datasets/downloads/ex...
# 23  /root/.cache/huggingface/datasets/downloads/ex...
# 24  /root/.cache/huggingface/datasets/downloads/ex...
# 25  /root/.cache/huggingface/datasets/downloads/ex...
# 26  /root/.cache/huggingface/datasets/downloads/ex...
# 27  /root/.cache/huggingface/datasets/downloads/ex...
# 28  /root/.cache/huggingface/datasets/downloads/ex...
# 29  /root/.cache/huggingface/datasets/downloads/ex...
# 30  /root/.cache/huggingface/datasets/downloads/ex...
# 31  /root/.cache/huggingface/datasets/downloads/ex...
# 32  /root/.cache/huggingface/datasets/downloads/ex...
# 33  /root/.cache/huggingface/datasets/downloads/ex...
# 34  /root/.cache/huggingface/datasets/downloads/ex...
# 35  /root/.cache/huggingface/datasets/downloads/ex...
# 36  /root/.cache/huggingface/datasets/downloads/ex...
# 37  /root/.cache/huggingface/datasets/downloads/ex...
# 38  /root/.cache/huggingface/datasets/downloads/ex...
# 39  /root/.cache/huggingface/datasets/downloads/ex...
# 40  /root/.cache/huggingface/datasets/downloads/ex...
# 41  /root/.cache/huggingface/datasets/downloads/ex...
# 42  /root/.cache/huggingface/datasets/downloads/ex...
# 43  /root/.cache/huggingface/datasets/downloads/ex...
# 44  /root/.cache/huggingface/datasets/downloads/ex...
# 45  /root/.cache/huggingface/datasets/downloads/ex...
# 46  /root/.cache/huggingface/datasets/downloads/ex...
# 47  /root/.cache/huggingface/datasets/downloads/ex...
# 48  /root/.cache/huggingface/datasets/downloads/ex...
# 49  /root/.cache/huggingface/datasets/downloads/ex...
# 50  /root/.cache/huggingface/datasets/downloads/ex...
#
#                                                 array  sampling_rate
# 0   [-0.005340576171875, -0.004791259765625, -0.00...          16000
# 1   [-0.001129150390625, -0.001190185546875, -0.00...          16000
# 2   [0.014007568359375, 0.0140380859375, 0.0124206...          16000
# 3   [-0.001190185546875, -0.00128173828125, -0.000...          16000
# 4   [0.07452392578125, 0.05059814453125, 0.0300292...          16000
# 5   [0.038238525390625, 0.0269775390625, 0.0199890...          16000
# 6   [0.001983642578125, -0.0028076171875, -0.00152...          16000
# 7   [0.017974853515625, -0.020294189453125, -0.018...          16000
# 8   [-0.005035400390625, 0.001007080078125, 0.0037...          16000
# 9   [-0.000335693359375, -0.000396728515625, -0.00...          16000
# 10  [-0.002593994140625, 0.00177001953125, -0.0029...          16000
# 11  [0.0, 3.0517578125e-05, -6.103515625e-05, -9.1...          16000
# 12  [-0.00152587890625, -0.00250244140625, -0.0009...          16000
# 13  [-0.00726318359375, 0.0023193359375, 0.0048522...          16000
# 14  [0.000213623046875, -3.0517578125e-05, 6.10351...          16000
# 15  [0.000152587890625, -0.0003662109375, -0.00317...          16000
# 16  [-0.005279541015625, -0.0052490234375, -0.0061...          16000
# 17  [0.001861572265625, 0.00946044921875, 0.004943...          16000
# 18  [-0.000457763671875, -0.000823974609375, 0.0, ...          16000
# 19  [-0.005096435546875, -0.000213623046875, 0.001...          16000
# 20  [0.003631591796875, 0.006072998046875, 0.00708...          16000
# 21  [0.02520751953125, 0.022308349609375, 0.012023...          16000
# 22  [-0.000213623046875, 0.028228759765625, -0.011...          16000
# 23  [0.00128173828125, -0.000335693359375, -0.0037...          16000
# 24  [0.0184326171875, -0.011383056640625, -0.00473...          16000
# 25  [0.013458251953125, 0.02227783203125, -0.00170...          16000
# 26  [-0.00372314453125, -0.014404296875, -0.008300...          16000
# 27  [0.000244140625, 9.1552734375e-05, 9.155273437...          16000
# 28  [0.003204345703125, 0.003204345703125, -0.0007...          16000
# 29  [0.000457763671875, 0.000457763671875, -0.0002...          16000
# 30  [-3.0517578125e-05, 0.005462646484375, 0.00570...          16000
# 31  [0.00640869140625, 0.00018310546875, -0.009338...          16000
# 32  [0.0042724609375, 0.00750732421875, 0.00759887...          16000
# 33  [0.0009765625, 0.001129150390625, 0.0013122558...          16000
# 34  [-0.0469970703125, -0.035980224609375, -0.0505...          16000
# 35  [0.00018310546875, 0.000518798828125, 0.001190...          16000
# 36  [0.13348388671875, 0.02728271484375, -0.005157...          16000
# 37  [0.000885009765625, -0.00213623046875, 0.00183...          16000
# 38  [0.00396728515625, 0.003875732421875, -0.00085...          16000
# 39  [-0.0260009765625, -0.00830078125, 0.006805419...          16000
# 40  [-0.00250244140625, -0.00341796875, -0.0020141...          16000
# 41  [-0.0006103515625, 0.000213623046875, 0.000640...          16000
# 42  [0.0001220703125, 0.017364501953125, 0.0243530...          16000
# 43  [0.004425048828125, 0.002105712890625, -0.0058...          16000
# 44  [0.00970458984375, 0.003570556640625, -0.00076...          16000
# 45  [-0.000640869140625, -0.000457763671875, 0.000...          16000
# 46  [-0.00732421875, -0.011383056640625, -0.013763...          16000
# 47  [0.121185302734375, 0.08197021484375, 0.012573...          16000
# 48  [-0.022705078125, -0.0191650390625, -0.0085144...          16000
# 49  [-0.000213623046875, 0.002471923828125, 0.0037...          16000
# 50  [0.0037841796875, 0.0035400390625, -0.00048828...          16000

# %%
male_samples=file.loc[file['Gender'] == 'male']
male_samples
# Out:
#    Gender                                         Transcript  \
# 0    male  esiteks on oluline et euroopa liit tuleks välj...
# 1    male  härra eesistuja juba süüria kodusõda tekitas s...
# 2    male  ja lõpetuseks tuleb kehtestada rahvusvahelised...
# 9    male  õigusriiki ja demokraatiat tugevdavaid reforme...
# 10   male  samas on mitme idapartnerluse riigi puhul jätk...
# 11   male  ja energialiiduna võib ühel päeval olla palju ...
# 12   male  me oleme olnud liiga palju üllatunud venemaa k...
# 14   male  põgenikud nende abistamine peab olema euroopa ...
# 19   male  novembrikuisel idapartnerluse tippkohtumisel t...
# 22   male  kuidas te hindate viimasel ajal serbia mõju om...
# 23   male  need konfliktid pidurdavad oluliselt meie idap...
# 27   male  minu küsimus puudutab selles piirkonnas olulis...
# 28   male  seetõttu on väga oluline säilitada euroopa lii...
# 33   male  inimesed põgenevad nii assadi režiimi kui ka i...
# 35   male  seni kuni euroopa liit arutab analüüsib ja mõt...
# 37   male  mul on hea meel et eesti on euroopa liidu eesi...
# 42   male  mul on väga kahju et fraktsioon gue hääletab s...
# 48   male  vajadusel tuleb arenguabi vahendeid ka suunata...
# 50   male  see et venemaa on asunud süürias tegutsema ei ...
#
#                                                  path  \
# 0   /root/.cache/huggingface/datasets/downloads/ex...
# 1   /root/.cache/huggingface/datasets/downloads/ex...
# 2   /root/.cache/huggingface/datasets/downloads/ex...
# 9   /root/.cache/huggingface/datasets/downloads/ex...
# 10  /root/.cache/huggingface/datasets/downloads/ex...
# 11  /root/.cache/huggingface/datasets/downloads/ex...
# 12  /root/.cache/huggingface/datasets/downloads/ex...
# 14  /root/.cache/huggingface/datasets/downloads/ex...
# 19  /root/.cache/huggingface/datasets/downloads/ex...
# 22  /root/.cache/huggingface/datasets/downloads/ex...
# 23  /root/.cache/huggingface/datasets/downloads/ex...
# 27  /root/.cache/huggingface/datasets/downloads/ex...
# 28  /root/.cache/huggingface/datasets/downloads/ex...
# 33  /root/.cache/huggingface/datasets/downloads/ex...
# 35  /root/.cache/huggingface/datasets/downloads/ex...
# 37  /root/.cache/huggingface/datasets/downloads/ex...
# 42  /root/.cache/huggingface/datasets/downloads/ex...
# 48  /root/.cache/huggingface/datasets/downloads/ex...
# 50  /root/.cache/huggingface/datasets/downloads/ex...
#
#                                                 array  sampling_rate
# 0   [-0.005340576171875, -0.004791259765625, -0.00...          16000
# 1   [-0.001129150390625, -0.001190185546875, -0.00...          16000
# 2   [0.014007568359375, 0.0140380859375, 0.0124206...          16000
# 9   [-0.000335693359375, -0.000396728515625, -0.00...          16000
# 10  [-0.002593994140625, 0.00177001953125, -0.0029...          16000
# 11  [0.0, 3.0517578125e-05, -6.103515625e-05, -9.1...          16000
# 12  [-0.00152587890625, -0.00250244140625, -0.0009...          16000
# 14  [0.000213623046875, -3.0517578125e-05, 6.10351...          16000
# 19  [-0.005096435546875, -0.000213623046875, 0.001...          16000
# 22  [-0.000213623046875, 0.028228759765625, -0.011...          16000
# 23  [0.00128173828125, -0.000335693359375, -0.0037...          16000
# 27  [0.000244140625, 9.1552734375e-05, 9.155273437...          16000
# 28  [0.003204345703125, 0.003204345703125, -0.0007...          16000
# 33  [0.0009765625, 0.001129150390625, 0.0013122558...          16000
# 35  [0.00018310546875, 0.000518798828125, 0.001190...          16000
# 37  [0.000885009765625, -0.00213623046875, 0.00183...          16000
# 42  [0.0001220703125, 0.017364501953125, 0.0243530...          16000
# 48  [-0.022705078125, -0.0191650390625, -0.0085144...          16000
# 50  [0.0037841796875, 0.0035400390625, -0.00048828...          16000

# %%
female_samples=file.loc[file['Gender'] == 'female']
female_samples
# Out:
#     Gender                                         Transcript  \
# 3   female  eelnimetatud rahvusvahelise õiguse rikkumised ...
# 4   female  mulle meeldib väga punkt üks kus öeldakse et i...
# 5   female  ja ma loeksin ette hea meelega resolutsiooni p...
# 6   female  siin on suur tähtsus mitteformaalse ja informa...
# 7   female  elu kinnitas taas kord et ida eurooplaste kann...
# 8   female  euroopa liidule ja eriti rahva poolt otse vali...
# 13  female  muidugi ma eeldan seda et ukraina jätkab oma r...
# 15  female  meie kohus on näidata et selline käitumine ei ...
# 16  female  kuid globaalne majanduskriis õõnestas meie usk...
# 17  female  kahjuks andis eilsel väliskomisjoni ja moldova...
# 18  female  need arengud ei toimu mitte ainult tänu riigia...
# 20  female  ettepanekud peaksid hõlmama ka reforme et liht...
# 21  female         ö universaalsete meetmete kooskõlastamine.
# 24  female  raportiga teeme sammu euroopa sotsiaalstandart...
# 25  female  aga vaatamata sellele me pingutasime kärpisime...
# 26  female  me tahame teada kuidas käitus politsei valimis...
# 29  female  me kordame resolutsioonis üle et venemaal dets...
# 30  female  aga venemaa ei ole vangistanud mitte ainult uk...
# 31  female  kuigi tegemist on väikese ja abivajava riigiga...
# 32  female  ja ma toetasin seda resolutsiooni ja jagan pal...
# 34  female  me ei lepi sellega kuna eurointegratsioon tähe...
# 36  female  mina nii ei arva ja seetõttu ma hääletasin ka ...
# 38  female  me peame leidma ühise valemi ühise arusaama mi...
# 39  female  paindlik haridustee saab olla abiks eeskätt ha...
# 40  female  euroopa liidu ja moldova suhted jäävad endisel...
# 41  female  nagu näiteks tööjõus osalemise määr noorte töö...
# 43  female  küll aga toetan seda resolutsiooni kui komprom...
# 44  female  enamgi veel need näitajad muudetakse võrdseks ...
# 45  female  käivitatud on ka riigihangete e platvorm ja võ...
# 46  female  eesmärk peab olema ebavõrdsuse ja palgavaesuse...
# 47  female  nimelt ütleb punkt kuus seda et me kutsume ven...
# 49  female  austatud istungi juhataja! mul on väga hea mee...
#
#                                                  path  \
# 3   /root/.cache/huggingface/datasets/downloads/ex...
# 4   /root/.cache/huggingface/datasets/downloads/ex...
# 5   /root/.cache/huggingface/datasets/downloads/ex...
# 6   /root/.cache/huggingface/datasets/downloads/ex...
# 7   /root/.cache/huggingface/datasets/downloads/ex...
# 8   /root/.cache/huggingface/datasets/downloads/ex...
# 13  /root/.cache/huggingface/datasets/downloads/ex...
# 15  /root/.cache/huggingface/datasets/downloads/ex...
# 16  /root/.cache/huggingface/datasets/downloads/ex...
# 17  /root/.cache/huggingface/datasets/downloads/ex...
# 18  /root/.cache/huggingface/datasets/downloads/ex...
# 20  /root/.cache/huggingface/datasets/downloads/ex...
# 21  /root/.cache/huggingface/datasets/downloads/ex...
# 24  /root/.cache/huggingface/datasets/downloads/ex...
# 25  /root/.cache/huggingface/datasets/downloads/ex...
# 26  /root/.cache/huggingface/datasets/downloads/ex...
# 29  /root/.cache/huggingface/datasets/downloads/ex...
# 30  /root/.cache/huggingface/datasets/downloads/ex...
# 31  /root/.cache/huggingface/datasets/downloads/ex...
# 32  /root/.cache/huggingface/datasets/downloads/ex...
# 34  /root/.cache/huggingface/datasets/downloads/ex...
# 36  /root/.cache/huggingface/datasets/downloads/ex...
# 38  /root/.cache/huggingface/datasets/downloads/ex...
# 39  /root/.cache/huggingface/datasets/downloads/ex...
# 40  /root/.cache/huggingface/datasets/downloads/ex...
# 41  /root/.cache/huggingface/datasets/downloads/ex...
# 43  /root/.cache/huggingface/datasets/downloads/ex...
# 44  /root/.cache/huggingface/datasets/downloads/ex...
# 45  /root/.cache/huggingface/datasets/downloads/ex...
# 46  /root/.cache/huggingface/datasets/downloads/ex...
# 47  /root/.cache/huggingface/datasets/downloads/ex...
# 49  /root/.cache/huggingface/datasets/downloads/ex...
#
#                                                 array  sampling_rate
# 3   [-0.001190185546875, -0.00128173828125, -0.000...          16000
# 4   [0.07452392578125, 0.05059814453125, 0.0300292...          16000
# 5   [0.038238525390625, 0.0269775390625, 0.0199890...          16000
# 6   [0.001983642578125, -0.0028076171875, -0.00152...          16000
# 7   [0.017974853515625, -0.020294189453125, -0.018...          16000
# 8   [-0.005035400390625, 0.001007080078125, 0.0037...          16000
# 13  [-0.00726318359375, 0.0023193359375, 0.0048522...          16000
# 15  [0.000152587890625, -0.0003662109375, -0.00317...          16000
# 16  [-0.005279541015625, -0.0052490234375, -0.0061...          16000
# 17  [0.001861572265625, 0.00946044921875, 0.004943...          16000
# 18  [-0.000457763671875, -0.000823974609375, 0.0, ...          16000
# 20  [0.003631591796875, 0.006072998046875, 0.00708...          16000
# 21  [0.02520751953125, 0.022308349609375, 0.012023...          16000
# 24  [0.0184326171875, -0.011383056640625, -0.00473...          16000
# 25  [0.013458251953125, 0.02227783203125, -0.00170...          16000
# 26  [-0.00372314453125, -0.014404296875, -0.008300...          16000
# 29  [0.000457763671875, 0.000457763671875, -0.0002...          16000
# 30  [-3.0517578125e-05, 0.005462646484375, 0.00570...          16000
# 31  [0.00640869140625, 0.00018310546875, -0.009338...          16000
# 32  [0.0042724609375, 0.00750732421875, 0.00759887...          16000
# 34  [-0.0469970703125, -0.035980224609375, -0.0505...          16000
# 36  [0.13348388671875, 0.02728271484375, -0.005157...          16000
# 38  [0.00396728515625, 0.003875732421875, -0.00085...          16000
# 39  [-0.0260009765625, -0.00830078125, 0.006805419...          16000
# 40  [-0.00250244140625, -0.00341796875, -0.0020141...          16000
# 41  [-0.0006103515625, 0.000213623046875, 0.000640...          16000
# 43  [0.004425048828125, 0.002105712890625, -0.0058...          16000
# 44  [0.00970458984375, 0.003570556640625, -0.00076...          16000
# 45  [-0.000640869140625, -0.000457763671875, 0.000...          16000
# 46  [-0.00732421875, -0.011383056640625, -0.013763...          16000
# 47  [0.121185302734375, 0.08197021484375, 0.012573...          16000
# 49  [-0.000213623046875, 0.002471923828125, 0.0037...          16000

# %%
def transcribe_audio(file_path):
    result = model.transcribe(file_path, language="et")
    return result["text"]

# %%
def calculate_wer(ground_truths, hypotheses):
    return wer(ground_truths, hypotheses)

# %%
total_wer = 0
num_sample = 0

for index,row in male_samples.iterrows():
    audio_path=row['path']
    ground_truth_text = row['Transcript']
    transcription = transcribe_audio(audio_path)
    # Compute metrics
    sample_wer = calculate_wer(ground_truth_text, transcription)

    total_wer += sample_wer
    num_sample += 1

    print(f"Processed {num_sample} files, WER: {sample_wer}")

# Calculate average metrics
average_wer = total_wer / num_sample

print(f"Average WER: {average_wer}")
# Out:
# Processed 1 files, WER: 0.6538461538461539
# Processed 2 files, WER: 0.6190476190476191
# Processed 3 files, WER: 0.6
# Processed 4 files, WER: 0.26666666666666666
# Processed 5 files, WER: 0.7857142857142857
# Processed 6 files, WER: 0.3235294117647059
# Processed 7 files, WER: 0.52
# Processed 8 files, WER: 0.5555555555555556
# Processed 9 files, WER: 0.6538461538461539
# Processed 10 files, WER: 1.0
# Processed 11 files, WER: 0.46153846153846156
# Processed 12 files, WER: 0.26666666666666666
# Processed 13 files, WER: 0.2777777777777778
# Processed 14 files, WER: 0.5
# Processed 15 files, WER: 0.47058823529411764
# Processed 16 files, WER: 0.6842105263157895
# Processed 17 files, WER: 0.3902439024390244
# Processed 18 files, WER: 0.15384615384615385
# Processed 19 files, WER: 0.3333333333333333
# Average WER: 0.5008637317711825

# %%
total_wer = 0
num_sample = 0

for index,row in female_samples.iterrows():
    audio_path=row['path']
    ground_truth_text = row['Transcript']
    transcription = transcribe_audio(audio_path)
    # Compute metrics
    sample_wer = calculate_wer(ground_truth_text, transcription)

    total_wer += sample_wer
    num_sample += 1

    print(f"Processed {num_sample} files, WER: {sample_wer}")

# Calculate average metrics
average_wer = total_wer / num_sample

print(f"Average WER: {average_wer}")
# Out:
# Processed 1 files, WER: 0.3157894736842105
# Processed 2 files, WER: 0.5217391304347826
# Processed 3 files, WER: 0.4090909090909091
# Processed 4 files, WER: 0.4666666666666667
# Processed 5 files, WER: 0.4583333333333333
# Processed 6 files, WER: 0.47058823529411764
# Processed 7 files, WER: 0.3181818181818182
# Processed 8 files, WER: 0.35714285714285715
# Processed 9 files, WER: 0.5
# Processed 10 files, WER: 0.47368421052631576
# Processed 11 files, WER: 0.35714285714285715
# Processed 12 files, WER: 0.3
# Processed 13 files, WER: 1.0
# Processed 14 files, WER: 0.5384615384615384
# Processed 15 files, WER: 0.3125
# Processed 16 files, WER: 0.5555555555555556
# Processed 17 files, WER: 0.4666666666666667
# Processed 18 files, WER: 0.43478260869565216
# Processed 19 files, WER: 0.29411764705882354
# Processed 20 files, WER: 0.3888888888888889
# Processed 21 files, WER: 0.3333333333333333
# Processed 22 files, WER: 0.5
# Processed 23 files, WER: 0.6470588235294118
# Processed 24 files, WER: 0.35294117647058826
# Processed 25 files, WER: 0.4666666666666667
# Processed 26 files, WER: 0.35294117647058826
# Processed 27 files, WER: 0.46153846153846156
# Processed 28 files, WER: 0.7222222222222222
# Processed 29 files, WER: 0.4444444444444444
# Processed 30 files, WER: 0.14285714285714285
# Processed 31 files, WER: 0.25925925925925924
# Processed 32 files, WER: 0.45161290322580644
# Average WER: 0.43981900021384124
